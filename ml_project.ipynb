# %%
# !pip install pandas numpy seaborn matplotlib scikit-learn joblib klib dtale pandas-profiling
# Out:
# Requirement already satisfied: pandas in /Applications/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: numpy in /Applications/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: seaborn in /Applications/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: matplotlib in /Applications/anaconda3/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /Applications/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: joblib in /Applications/anaconda3/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: klib in /Applications/anaconda3/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: dtale in /Applications/anaconda3/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: pandas-profiling in /Applications/anaconda3/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in /Applications/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Applications/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /Applications/anaconda3/lib/python3.11/site-packages (from klib) (3.1.2)
# Requirement already satisfied: plotly<6.0.0,>=5.2.2 in /Applications/anaconda3/lib/python3.11/site-packages (from klib) (5.9.0)
# Requirement already satisfied: screeninfo<0.9.0,>=0.8.1 in /Applications/anaconda3/lib/python3.11/site-packages (from klib) (0.8.1)
# Requirement already satisfied: dash-colorscales in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (1.14)
# Requirement already satisfied: future>=0.14.0 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.18.3)
# Requirement already satisfied: kaleido in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: missingno in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.5.2)
# Requirement already satisfied: squarify in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.4.3)
# Requirement already satisfied: strsimpy in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (4.12.2)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2023.7.22)
# Requirement already satisfied: flask-ngrok in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.0.25)
# Requirement already satisfied: lz4 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (4.3.2)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (1.3.1)
# Requirement already satisfied: networkx in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (3.1)
# Requirement already satisfied: statsmodels in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (0.14.0)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (3.0.10)
# Requirement already satisfied: xarray in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2023.6.0)
# Requirement already satisfied: dash in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.13.0)
# Requirement already satisfied: et-xmlfile in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (1.1.0)
# Requirement already satisfied: Flask<2.3 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.2.2)
# Requirement already satisfied: itsdangerous in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.0.1)
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.31.0)
# Requirement already satisfied: werkzeug<2.3 in /Applications/anaconda3/lib/python3.11/site-packages (from dtale) (2.2.3)
# Requirement already satisfied: pydantic>=1.8.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (2.3.0)
# Requirement already satisfied: PyYAML>=5.0.0 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: markupsafe~=2.1.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: htmlmin>=0.1.12 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: phik>=0.11.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: tqdm>=4.48.2 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: multimethod>=1.4 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: attrs>=19.3.0 in /Applications/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: imagehash in /Applications/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (4.7.1)
# Requirement already satisfied: retrying in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: ansi2html in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (1.8.0)
# Requirement already satisfied: nest-asyncio in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (1.5.6)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.11/site-packages (from dash->dtale) (68.0.0)
# Requirement already satisfied: click>=8.0 in /Applications/anaconda3/lib/python3.11/site-packages (from Flask<2.3->dtale) (8.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from plotly<6.0.0,>=5.2.2->klib) (8.2.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Applications/anaconda3/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /Applications/anaconda3/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (2.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/anaconda3/lib/python3.11/site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.11/site-packages (from requests->dtale) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.11/site-packages (from requests->dtale) (1.26.16)
# Requirement already satisfied: Cython in /Applications/anaconda3/lib/python3.11/site-packages (from screeninfo<0.9.0,>=0.8.1->klib) (3.0.2)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Applications/anaconda3/lib/python3.11/site-packages (from screeninfo<0.9.0,>=0.8.1->klib) (9.0)
# Requirement already satisfied: soupsieve>1.2 in /Applications/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->dtale) (2.4)
# Requirement already satisfied: brotli in /Applications/anaconda3/lib/python3.11/site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /Applications/anaconda3/lib/python3.11/site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: PyWavelets in /Applications/anaconda3/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Requirement already satisfied: pyobjc-core>=9.0 in /Applications/anaconda3/lib/python3.11/site-packages (from pyobjc-framework-Cocoa->screeninfo<0.9.0,>=0.8.1->klib) (9.0)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv("Train.csv")
df_test=pd.read_csv("Test.csv")

# %%
df_train.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
#df_test

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_train['Item_Weight'].describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean(),inplace=True)
df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean(),inplace=True)

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_train['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df_train['Outlet_Size'].fillna(df_train['Outlet_Size'].mode()[0],inplace=True)
df_test['Outlet_Size'].fillna(df_test['Outlet_Size'].mode()[0],inplace=True)

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998      Medium               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002      Medium               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df_train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
df_train.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)
df_test.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0     249.8092                       1999      Medium               Tier 1
# 1      48.2692                       2009      Medium               Tier 3
# 2     141.6180                       1999      Medium               Tier 1
# 3     182.0950                       1998      Medium               Tier 3
# 4      53.8614                       1987        High               Tier 3
# ...        ...                        ...         ...                  ...
# 8518  214.5218                       1987        High               Tier 3
# 8519  108.1570                       2002      Medium               Tier 2
# 8520   85.1224                       2004       Small               Tier 2
# 8521  103.1332                       2009      Medium               Tier 3
# 8522   75.4670                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 10 columns]

# %%
df_test
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0     107.8622                       1999      Medium               Tier 1
# 1      87.3198                       2007      Medium               Tier 2
# 2     241.7538                       1998      Medium               Tier 3
# 3     155.0340                       2007      Medium               Tier 2
# 4     234.2300                       1985      Medium               Tier 3
# ...        ...                        ...         ...                  ...
# 5676  141.3154                       1997       Small               Tier 1
# 5677  169.1448                       2009      Medium               Tier 3
# 5678  118.7440                       2002      Medium               Tier 2
# 5679  214.6218                       2007      Medium               Tier 2
# 5680   79.7960                       2002      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 9 columns]

# %% [markdown]
#   # EDA using dtale library

# %%
import dtale

# %%
dtale.show(df_train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://gavravs-MacBook-Air.local:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # EDA using klib library

# %%
import klib

# %%
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df_train)
# Out:
# <style type="text/css">
# #T_48b01_row0_col0, #T_48b01_row0_col2, #T_48b01_row0_col4, #T_48b01_row1_col1, #T_48b01_row2_col0, #T_48b01_row2_col2, #T_48b01_row2_col3, #T_48b01_row2_col4, #T_48b01_row3_col2, #T_48b01_row3_col3, #T_48b01_row4_col0, #T_48b01_row4_col2, #T_48b01_row4_col4 {
#   color: None;
# }
# #T_48b01_row0_col1, #T_48b01_row0_col3, #T_48b01_row1_col0, #T_48b01_row1_col2, #T_48b01_row1_col3, #T_48b01_row1_col4, #T_48b01_row2_col1, #T_48b01_row3_col0, #T_48b01_row3_col1, #T_48b01_row3_col4, #T_48b01_row4_col1, #T_48b01_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_48b01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48b01_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_48b01_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_48b01_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
#       <th id="T_48b01_level0_col3" class="col_heading level0 col3" >Outlet_Establishment_Year</th>
#       <th id="T_48b01_level0_col4" class="col_heading level0 col4" >Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48b01_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
#       <td id="T_48b01_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_48b01_row0_col1" class="data row0 col1" >-0.01</td>
#       <td id="T_48b01_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_48b01_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_48b01_row0_col4" class="data row0 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_48b01_level0_row1" class="row_heading level0 row1" >Item_Visibility</th>
#       <td id="T_48b01_row1_col0" class="data row1 col0" >-0.01</td>
#       <td id="T_48b01_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_48b01_row1_col2" class="data row1 col2" >-0.00</td>
#       <td id="T_48b01_row1_col3" class="data row1 col3" >-0.07</td>
#       <td id="T_48b01_row1_col4" class="data row1 col4" >-0.13</td>
#     </tr>
#     <tr>
#       <th id="T_48b01_level0_row2" class="row_heading level0 row2" >Item_MRP</th>
#       <td id="T_48b01_row2_col0" class="data row2 col0" >0.02</td>
#       <td id="T_48b01_row2_col1" class="data row2 col1" >-0.00</td>
#       <td id="T_48b01_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_48b01_row2_col3" class="data row2 col3" >0.01</td>
#       <td id="T_48b01_row2_col4" class="data row2 col4" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_48b01_level0_row3" class="row_heading level0 row3" >Outlet_Establishment_Year</th>
#       <td id="T_48b01_row3_col0" class="data row3 col0" >-0.01</td>
#       <td id="T_48b01_row3_col1" class="data row3 col1" >-0.07</td>
#       <td id="T_48b01_row3_col2" class="data row3 col2" >0.01</td>
#       <td id="T_48b01_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_48b01_row3_col4" class="data row3 col4" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_48b01_level0_row4" class="row_heading level0 row4" >Item_Outlet_Sales</th>
#       <td id="T_48b01_row4_col0" class="data row4 col0" >0.01</td>
#       <td id="T_48b01_row4_col1" class="data row4 col1" >-0.13</td>
#       <td id="T_48b01_row4_col2" class="data row4 col2" >0.57</td>
#       <td id="T_48b01_row4_col3" class="data row4 col3" >-0.05</td>
#       <td id="T_48b01_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.corr_plot(df_train)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train)
# Out:
# <Axes: xlabel='Item_Weight', ylabel='Density'>

# %%
klib.missingval_plot(df_train)
# Out:
# No missing values found in the dataset.

# %% [markdown]
# # data cleaning

# %%
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.46 MB (-70.77%)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
#         item_mrp  outlet_establishment_year outlet_size outlet_location_type  \
# 0     249.809204                       1999      Medium               Tier 1
# 1      48.269199                       2009      Medium               Tier 3
# 2     141.617996                       1999      Medium               Tier 1
# 3     182.095001                       1998      Medium               Tier 3
# 4      53.861401                       1987        High               Tier 3
# ...          ...                        ...         ...                  ...
# 8518  214.521805                       1987        High               Tier 3
# 8519  108.156998                       2002      Medium               Tier 2
# 8520   85.122398                       2004       Small               Tier 2
# 8521  103.133202                       2009      Medium               Tier 3
# 8522   75.467003                       1997       Small               Tier 1
#
#             outlet_type  item_outlet_sales
# 0     Supermarket Type1        3735.137939
# 1     Supermarket Type2         443.422791
# 2     Supermarket Type1        2097.270020
# 3         Grocery Store         732.380005
# 4     Supermarket Type1         994.705200
# ...                 ...                ...
# 8518  Supermarket Type1        2778.383301
# 8519  Supermarket Type1         549.284973
# 8520  Supermarket Type1        1193.113647
# 8521  Supermarket Type2        1845.597656
# 8522  Supermarket Type1         765.669983
#
# [8523 rows x 10 columns]

# %%
klib.clean_column_names(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
#       item_mrp  outlet_establishment_year outlet_size outlet_location_type  \
# 0     249.8092                       1999      Medium               Tier 1
# 1      48.2692                       2009      Medium               Tier 3
# 2     141.6180                       1999      Medium               Tier 1
# 3     182.0950                       1998      Medium               Tier 3
# 4      53.8614                       1987        High               Tier 3
# ...        ...                        ...         ...                  ...
# 8518  214.5218                       1987        High               Tier 3
# 8519  108.1570                       2002      Medium               Tier 2
# 8520   85.1224                       2004       Small               Tier 2
# 8521  103.1332                       2009      Medium               Tier 3
# 8522   75.4670                       1997       Small               Tier 1
#
#             outlet_type  item_outlet_sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 10 columns]

# %%
klib.convert_datatypes(df_train)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   float32
# dtypes: category(5), float32(4), int16(1)
# memory usage: 192.9 KB

# %%
klib.pool_duplicate_subsets(df_train)
# Out:
#       item_visibility  item_mrp  item_outlet_sales  pooled_vars
# 0            0.016047  249.8092          3735.1380            0
# 1            0.019278   48.2692           443.4228            1
# 2            0.016760  141.6180          2097.2700            2
# 3            0.000000  182.0950           732.3800            3
# 4            0.000000   53.8614           994.7052            4
# ...               ...       ...                ...          ...
# 8518         0.056783  214.5218          2778.3834         8518
# 8519         0.046982  108.1570           549.2850         8519
# 8520         0.035186   85.1224          1193.1136         8520
# 8521         0.145221  103.1332          1845.5976         8521
# 8522         0.044878   75.4670           765.6700         8522
#
# [8523 rows x 4 columns]

# %% [markdown]
# # label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_train=df_train.apply(le.fit_transform)

# %%
df_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 0             284                 1              664          4      5592
# 1              57                 2              880         14       473
# 2             376                 1              715         10      2901
# 3             393                 2                0          6      4227
# 4             265                 1                0          9       627
# ...           ...               ...              ...        ...       ...
# 8518          125                 1             3912         13      4955
# 8519          233                 2             3278          0      2023
# 8520          299                 1             2302          8      1263
# 8521          149                 2             7174         13      1857
# 8522          347                 1             3108         14      1011
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# 0                             4            1                     0
# 1                             8            1                     2
# 2                             4            1                     0
# 3                             3            1                     2
# 4                             1            0                     2
# ...                         ...          ...                   ...
# 8518                          1            0                     2
# 8519                          5            1                     1
# 8520                          6            2                     1
# 8521                          8            1                     2
# 8522                          2            2                     0
#
#       outlet_type  item_outlet_sales
# 0               1               2540
# 1               2                422
# 2               1               1639
# 3               0                670
# 4               1                865
# ...           ...                ...
# 8518            1               2047
# 8519            1                516
# 8520            1               1018
# 8521            2               1466
# 8522            1                697
#
# [8523 rows x 10 columns]

# %% [markdown]
# # spliting our data in to train and test

# %%
x=df_train.drop('item_outlet_sales',axis=1)

# %%
y=df_train['item_outlet_sales']

# %%
y
# Out:
# 0       2540
# 1        422
# 2       1639
# 3        670
# 4        865
#         ...
# 8518    2047
# 8519     516
# 8520    1018
# 8521    1466
# 8522     697
# Name: item_outlet_sales, Length: 8523, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=101,test_size=0.2)

# %%
x_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 3684          394                 1             6031          4       647
# 1935          182                 1             4178         14      1564
# 5142          395                 2             4417         10      3740
# 4978           86                 0             2018          4      4065
# 2299          368                 1             1151          4      2124
# ...           ...               ...              ...        ...       ...
# 599            10                 1             3048         14      4454
# 5695          344                 1             7532          7       707
# 8006          321                 1              845          8      1632
# 1361          290                 2             6833          0      5169
# 1547          358                 1             7408          9       741
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# 3684                          1            0                     2
# 1935                          7            1                     1
# 5142                          7            1                     1
# 4978                          2            2                     0
# 2299                          5            1                     1
# ...                         ...          ...                   ...
# 599                           2            2                     0
# 5695                          5            1                     1
# 8006                          2            2                     0
# 1361                          7            1                     1
# 1547                          8            1                     2
#
#       outlet_type
# 3684            1
# 1935            1
# 5142            1
# 4978            1
# 2299            1
# ...           ...
# 599             1
# 5695            1
# 8006            1
# 1361            1
# 1547            2
#
# [6818 rows x 9 columns]

# %%
x_test
# Out:
#       item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 8179          305                 1             3815          8      1753
# 8355          381                 1             2651         13      3152
# 3411          190                 2             4881          1      1062
# 7089          408                 1             3427          6       207
# 6954          175                 1             1624          3      3291
# ...           ...               ...              ...        ...       ...
# 1317          369                 1             6143         13      3381
# 4996          241                 1             1606         14      3308
# 531           357                 1             6318         11      4321
# 3891          372                 1                0          9      2252
# 6629           78                 2              189         10      3224
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# 8179                          8            1                     2
# 8355                          1            0                     2
# 3411                          2            2                     0
# 7089                          7            1                     1
# 6954                          5            1                     1
# ...                         ...          ...                   ...
# 1317                          4            1                     0
# 4996                          2            2                     0
# 531                           3            1                     2
# 3891                          8            1                     2
# 6629                          5            1                     1
#
#       outlet_type
# 8179            2
# 8355            1
# 3411            1
# 7089            1
# 6954            1
# ...           ...
# 1317            1
# 4996            1
# 531             0
# 3891            2
# 6629            1
#
# [1705 rows x 9 columns]

# %%
y_train
# Out:
# 3684     144
# 1935    1311
# 5142    1242
# 4978    1426
# 2299    2462
#         ...
# 599     3137
# 5695    1193
# 8006    1684
# 1361    2001
# 1547     746
# Name: item_outlet_sales, Length: 6818, dtype: int64

# %%
y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %% [markdown]
# # standarization

# %%
x.describe()
# Out:
#        item_weight  item_fat_content  item_visibility    item_type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean    298.756776          1.369354      3708.866127     7.226681
# std      95.451067          0.644810      2396.221439     4.209990
# min       0.000000          0.000000         0.000000     0.000000
# 25%     285.000000          1.000000      1595.500000     4.000000
# 50%     326.000000          1.000000      3708.000000     6.000000
# 75%     361.000000          2.000000      5788.500000    10.000000
# max     415.000000          4.000000      7878.000000    15.000000
#
#           item_mrp  outlet_establishment_year  outlet_size  \
# count  8523.000000                8523.000000  8523.000000
# mean   2941.096562                   3.790684     1.170832
# std    1675.483234                   2.730322     0.600327
# min       0.000000                   0.000000     0.000000
# 25%    1535.500000                   1.000000     1.000000
# 50%    2949.000000                   4.000000     1.000000
# 75%    4351.500000                   6.000000     2.000000
# max    5937.000000                   8.000000     2.000000
#
#        outlet_location_type  outlet_type
# count           8523.000000  8523.000000
# mean               1.112871     1.201220
# std                0.812757     0.796459
# min                0.000000     0.000000
# 25%                0.000000     1.000000
# 50%                1.000000     1.000000
# 75%                2.000000     1.000000
# max                2.000000     3.000000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train_std=sc.fit_transform(x_train)

# %%
x_test_std=sc.transform(x_test)

# %%
x_train_std
# Out:
# array([[ 1.00439018, -0.57382672,  0.9652137 , ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.23760194, -0.57382672,  0.19203621, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 1.01496562,  0.97378032,  0.29176067, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        ...,
#        [ 0.23238346, -0.57382672, -1.19868187, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        [-0.09545501,  0.97378032,  1.29985393, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 0.62367454, -0.57382672,  1.53977679, ..., -0.28872895,
#          1.08786619,  0.98524841]])

# %%
x_test_std
# Out:
# array([[ 0.06317651, -0.57382672,  0.04057186, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [ 0.86690953, -0.57382672, -0.44511546, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.15299846,  0.97378032,  0.48536798, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        ...,
#        [ 0.61309911, -0.57382672,  1.0849665 , ..., -0.28872895,
#          1.08786619, -1.50453056],
#        [ 0.77173062, -0.57382672, -1.55126416, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [-2.33744713,  0.97378032, -1.47240255, ..., -0.28872895,
#         -0.13870429, -0.25964107]])

# %% [markdown]
# # model building

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train_std,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(x_test_std)
print(y_pred_lr)
# Out:
# [1476.49656447 1434.20492577  919.4121698  ...  947.41970844 1685.68679797
#  1689.65501165]

# %%
y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(y_test,y_pred_lr))
print(mean_absolute_error(y_test,y_pred_lr))
print(np.sqrt(mean_squared_error(y_test,y_pred_lr)))
# Out:
# 0.5451913433113661
# 489.24868770146304
# 613.705419012412

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=1000)

# %%
rf.fit(x_train_std,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
y_pred_rf=rf.predict(x_test_std)

# %%
print(r2_score(y_test,y_pred_rf))
print(mean_absolute_error(y_test,y_pred_rf))
print(np.sqrt(mean_squared_error(y_test,y_pred_rf)))
# Out:
# 0.6132518128220106
# 430.2431102639296
# 565.9261216749755

# %% [markdown]
# # hyper parameter tuning

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# define model and parameters
model=RandomForestRegressor()
n_estimators=[10,100,1000]
max_depth=range(1,31)
min_samples_leaf=np.linspace(0.1,1.0)
max_features=["auto","sqrt","log2"]
min_samples_split=np.linspace(0.1,1.0,10)

# define grid search
grid=dict(n_estimators=n_estimators)
grid_search_forest=GridSearchCV(estimator=model,param_grid=grid,n_jobs=-1,scoring='r2',error_score=0,verbose=2,cv=2)
grid_search_forest.fit(x_train_std,y_train)

# summarize result
print(f"Best:{grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means=grid_search_forest.cv_results_['mean_test_score']
stds=grid_search_forest.cv_results_['std_test_score']
params=grid_search_forest.cv_results_['params']

for mean,stdev,param in zip(means,stds,params):
    print(f"{mean:.3f},({stdev:.3f})with:{param}")
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Best:0.622 using {'n_estimators': 1000}
# 0.590,(0.003)with:{'n_estimators': 10}
# 0.618,(0.002)with:{'n_estimators': 100}
# 0.622,(0.003)with:{'n_estimators': 1000}

# %%
grid_search_forest.best_params_
# Out:
# {'n_estimators': 1000}

# %%
grid_search_forest.best_score_
# Out:
# 0.6216702208763902

# %%
y_pred_rf_grid=grid_search_forest.predict(x_test_std)

# %%
r2_score(y_test,y_pred_rf_grid)
# Out:
# 0.614941050993552
